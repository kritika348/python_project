# %% [markdown]
# <a href="https://colab.research.google.com/github/kritika348/python_project/blob/main/quiz_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''quiz'''
questions = {
    "What is the capital of India? ": "delhi",
    "Which language are we learning? ": "python",
    "What is 5 + 5? ": "10",
    "Which keyword is used to define a function? ": "def",
    "What is the extension of Python files? ": ".py"
}

score = 0

print("=== Python Quiz ===")

for question, answer in questions.items():
    user_answer = input(question).lower()

    if user_answer == answer:
        print("Correct!")
        score += 1
    else:
        print("Wrong!")

print("\nYour score:", score, "/", len(questions))
# Out:
# === Python Quiz ===
# What is the capital of India? delhi
# Correct!
# Which language are we learning? java
# Wrong!
# What is 5 + 5? 10
# Correct!
# Which keyword is used to define a function? def
# Correct!
# What is the extension of Python files? .py
# Correct!
#
# Your score: 4 / 5
