# %% [markdown]
# <a href="https://colab.research.google.com/github/kritika348/python_project/blob/main/grade__calculator_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("======================================")
print("       STUDENT GRADE CALCULATOR")
print("======================================")

name = input("Enter student name: ")

print("\nEnter marks out of 100")

english = float(input("English: "))
maths = float(input("Maths: "))
science = float(input("Science: "))
computer = float(input("Computer: "))
hindi = float(input("Hindi: "))

total = english + maths + science + computer + hindi

percentage = total / 5

if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
elif percentage >= 40:
    grade = "E"
else:
    grade = "F"

if percentage >= 40:
    result = "PASS"
else:
    result = "FAIL"

print("\n======================================")
print("             RESULT")
print("======================================")

print("Student Name :", name)
print("English      :", english)
print("Maths        :", maths)
print("Science      :", science)
print("Computer     :", computer)
print("Hindi        :", hindi)

print("Total Marks  :", total, "/ 500")
print("Percentage   :", percentage, "%")
print("Grade        :", grade)
print("Result       :", result)
# Out:
# ...
#        STUDENT GRADE CALCULATOR
# ...
# Enter student name: khushi
#
# Enter marks out of 100
# English: 34
# Maths: 67
# Science: 45
# Computer: 34
# Hindi: 45
#
# ...
#              RESULT
# ...
# Student Name : khushi
# English      : 34.0
# Maths        : 67.0
# Science      : 45.0
# Computer     : 34.0
# Hindi        : 45.0
# Total Marks  : 225.0 / 500
# Percentage   : 45.0 %
# Grade        : E
# Result       : PASS
