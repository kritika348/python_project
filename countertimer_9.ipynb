# %% [markdown]
# <a href="https://colab.research.google.com/github/kritika348/python_project/blob/main/countertimer_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

print("================================")
print("       COUNTDOWN TIMER")
print("================================")

minutes = int(input("Enter minutes: "))
seconds = int(input("Enter seconds: "))

total_seconds = minutes * 60 + seconds

print("\nTimer Started!\n")

while total_seconds > 0:
    mins = total_seconds // 60
    secs = total_seconds % 60

    print(f"\rTime Remaining: {mins:02d}:{secs:02d}", end="")

    time.sleep(1)
    total_seconds -= 1

print("\rTime Remaining: 00:00")
# Out:
# ...
#        COUNTDOWN TIMER
# ...
#
# Timer Started!
#
# Time Remaining: 16:01
