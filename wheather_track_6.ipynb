# %% [markdown]
# <a href="https://colab.research.google.com/github/kritika348/python_project/blob/main/wheather_track_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

city = input("Enter city name: ")


geo_url = "https://geocoding-api.open-meteo.com/v1/search"

geo_params = {
    "name": city,
    "count": 1,
    "language": "en",
    "format": "json"
}

geo_response = requests.get(geo_url, params=geo_params)
geo_data = geo_response.json()

if "results" not in geo_data:
    print("City not found!")

else:
    latitude = geo_data["results"][0]["latitude"]
    longitude = geo_data["results"][0]["longitude"]

    # Weather API
    weather_url = "https://api.open-meteo.com/v1/forecast"

    weather_params = {
        "latitude": latitude,
        "longitude": longitude,
        "current": "temperature_2m,relative_humidity_2m,wind_speed_10m"
    }

    response = requests.get(weather_url, params=weather_params)
    data = response.json()

    current = data["current"]

    print("\n🌦️ WEATHER REPORT")
    print("----------------------")
    print("City:", city)
    print("🌡️ Temperature:", current["temperature_2m"], "°C")
    print("💧 Humidity:", current["relative_humidity_2m"], "%")
    print("💨 Wind Speed:", current["wind_speed_10m"], "km/h")
# Out:
# Enter city name: delhi
#
# 🌦️ WEATHER REPORT
# ----------------------
# City: delhi
# 🌡️ Temperature: 29.1 °C
# 💧 Humidity: 81 %
# 💨 Wind Speed: 6.4 km/h
