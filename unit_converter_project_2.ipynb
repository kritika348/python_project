# %% [markdown]
# <a href="https://colab.research.google.com/github/kritika348/python_project/blob/main/unit_converter_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''unit converter'''
print("=== Unit Converter ===")
print("1. Kilometers to Miles")
print("2. Miles to Kilometers")
print("3. Celsius to Fahrenheit")
print("4. Fahrenheit to Celsius")

choice = input("Enter choice: ")
value = float(input("Enter value: "))

if choice == "1":
    print("Miles:", value * 0.621371)

elif choice == "2":
    print("Kilometers:", value * 1.60934)

elif choice == "3":
    print("Fahrenheit:", (value * 9/5) + 32)

elif choice == "4":
    print("Celsius:", (value - 32) * 5/9)

else:
    print("Invalid choice.")
# Out:
# === Unit Converter ===
# 1. Kilometers to Miles
# 2. Miles to Kilometers
# 3. Celsius to Fahrenheit
# 4. Fahrenheit to Celsius
